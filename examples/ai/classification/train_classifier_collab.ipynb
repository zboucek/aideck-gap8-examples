# %% [markdown]
# # Fine-Tuning and Quantization of MobileNetV3 for AI Deck
#
# This notebook demonstrates the process of fine-tuning a pre-trained MobileNetV3Small model on a custom dataset and quantizing it for deployment on the AI Deck. The AI Deck is a powerful tool for running lightweight AI models on drones, and optimizing models for it involves careful consideration of size, accuracy, and compatibility.
#
# The notebook is divided into the following sections:
#
# 1. **Data Preparation**: Loading and augmenting the dataset.
# 2. **Model Definition**: Setting up a MobileNetV3-based architecture.
# 3. **Training**: Fine-tuning the model for our custom dataset.
# 4. **Evaluation**: Assessing the model's performance.
# 5. **Model Conversion and Quantization**: Preparing the model for deployment on the AI Deck.
# 6. **Testing the Quantized Model**: Verifying the functionality of the quantized model.

# %% [markdown]
# ## Prerequisites
#
# Before running this notebook, ensure you have the following installed and configured:
#
# 1. **Python Environment**:
#    - Python 3.8–3.11
#    - A virtual environment or Conda environment is recommended to manage dependencies.
#
# 2. **Required Libraries**:
#    - `TensorFlow >= 2.10`
#    - `NumPy`
#    - `Pandas`
#    - `Matplotlib`
#    - `Pillow`
#    - `SciPy`
#    - `Seaborn`
#    - `PyDot`
#    - `GraphViz`
#
#    You can install the required libraries with:
#    ```bash
#    pip install tensorflow numpy pandas matplotlib pillow scipy pydot
#
#    sudo apt install graphviz
#    ```
#
# 3. **Dataset**:
#
#    - A labeled dataset organized in the following structure:
#
#     training_data/
#       train/
#         class1/
#         class2/
#         ...
#       validation/
#         class1/
#         class2/
#         ...
#
#    - Ensure the dataset is prepared with appropriate augmentations for training.
#    - For a quick start, you can use the provided example dataset: `training_data/training_data_christmas_packet.zip` Extract the archive to a folder before running the notebook.
#
# 4. **Hardware**:
#
#    - A GPU-enabled machine is recommended for faster training.
#     Ensure TensorFlow is configured to use your GPU if available.
#
# 5. **AI Deck Environment (for deployment)**:
#
#    - Install the necessary tools and libraries to work with the AI Deck.
#
# Refer to the official [AI Deck documentation](https://www.bitcraze.io/documentation/tutorials/getting-started-with-aideck/) documentation for setup instructions or README.

# %%
# !pip install tensorflow numpy pandas matplotlib pillow scipy pydot
# !sudo apt install graphviz
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: pandas in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: matplotlib in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (3.10.0)
# Requirement already satisfied: pillow in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (11.1.0)
# Requirement already satisfied: scipy in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (1.15.0)
# Requirement already satisfied: pydot in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (4.0.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (75.6.0)
# Requirement already satisfied: six>=1.12.0 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (1.69.0)
# Collecting tensorboard~=2.19.0 (from tensorflow)
#   Using cached tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.5.0 (from tensorflow)
#   Downloading keras-3.10.0-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: h5py>=3.11.0 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (3.12.1)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Collecting rich (from keras>=3.5.0->tensorflow)
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.5.0->tensorflow)
#   Downloading namex-0.0.9-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow)
#   Downloading optree-0.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.5.0->tensorflow)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (644.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 MB 29.6 MB/s eta 0:00:0000:0100:01
# Downloading keras-3.10.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 7.5 MB/s eta 0:00:00
# Downloading ml_dtypes-0.5.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 19.6 MB/s eta 0:00:0000:01
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 22.0 MB/s eta 0:00:00a 0:00:01
# Downloading namex-0.0.9-py3-none-any.whl (5.8 kB)
# Downloading optree-0.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (410 kB)
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, optree, ml-dtypes, mdurl, tensorboard, markdown-it-py, rich, keras, tensorflow
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
#       Successfully uninstalled tensorboard-2.14.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# intel-tensorflow 2.14.0 requires keras<2.15,>=2.14.0, but you have keras 3.10.0 which is incompatible.
# intel-tensorflow 2.14.0 requires ml-dtypes==0.2.0, but you have ml-dtypes 0.5.1 which is incompatible.
# intel-tensorflow 2.14.0 requires tensorboard<2.15,>=2.14, but you have tensorboard 2.19.0 which is incompatible.
# Successfully installed keras-3.10.0 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.5.1 namex-0.0.9 optree-0.15.0 rich-14.0.0 tensorboard-2.19.0 tensorflow-2.19.0
# [sudo] password for zboucek:

# %% [markdown]
# ## Imports

# %%
import os
import argparse
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from PIL import Image
import zipfile

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Input,
    Resizing,
    Conv2D,
    GlobalAveragePooling2D,
    Dropout,
    Dense
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Prepare the Dataset and Initialize Arguments
# This section uses command-line style argument parsing adapted for the notebook environment. It initializes parameters and ensures the dataset is prepared.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Vytvoř si složku pro modely a data
import os
DRIVE_PATH = '/content/drive/MyDrive/aideck'
os.makedirs(DRIVE_PATH, exist_ok=True)

# Emulate argparse in Jupyter
class Args:
    epochs = 80
    finetune_epochs = 40
    dataset_path = "training_data"
    batch_size = 32
    image_width = 324
    image_height = 244
    image_channels = 3
    print_plot = True

args = Args()


if args.image_channels == 1:
    color_mode = "grayscale"
else:
    color_mode = "rgb"

(train_images, train_labels), (val_images, val_labels) = tf.keras.datasets.mnist.load_data()


# 4) Preprocess: scale pixel values to [0, 1]
train_images = train_images.astype('float32') / 255.0
val_images   = val_images.astype('float32') / 255.0

# 5) Add channel dimension
if args.image_channels == 1:
    train_images = train_images[..., None]  # shape -> (60000, 28, 28, 1)
    val_images   = val_images[...,   None]
else:
    # If you ever want RGB versions
    train_images = tf.image.grayscale_to_rgb(train_images[..., None]).numpy()
    val_images   = tf.image.grayscale_to_rgb(val_images[...,   None]).numpy()

# 6) One-hot encode labels
num_classes = 10
train_labels = to_categorical(train_labels, num_classes)
val_labels   = to_categorical(val_labels,   num_classes)

# Data augmentation for the training dataset
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1.0 / 255.0,  # Normalize pixel values to [0, 1]
    rotation_range=15,  # Randomly rotate images within ±15°
    shear_range=0.2,  # Apply random shearing transformations up to 20%
    zoom_range=0.2,  # Randomly zoom in/out up to ±20%
    width_shift_range=0.1,  # Horizontally shift images by up to 10%
    height_shift_range=0.1,  # Vertically shift images by up to 10%
    horizontal_flip=True,  # Allow horizontal flipping of images
    vertical_flip=False,  # Skip vertical flipping (not logical for this dataset)
    brightness_range=[0.5, 1.5]  # Randomly adjust brightness between 50% and 150%
)

# Data augmentation for the validation dataset
# Only rescaling is applied to ensure consistency in validation
val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1.0 / 255.0  # Normalize pixel values to [0, 1]
)


train_generator = train_datagen.flow(
    train_images,
    train_labels,
    batch_size=args.batch_size,
    shuffle=True
)


# Validation generator—only rescaling (already in [0,1])
val_datagen = ImageDataGenerator()
val_generator = val_datagen.flow(
    val_images,
    val_labels,
    batch_size=args.batch_size,
    shuffle=False
)

# 8) Save class labels (0–9) for later inference
labels = [str(i) for i in range(num_classes)]
with open(os.path.join(DRIVE_PATH, "class_labels.txt"), "w") as f:
    f.write("\n".join(labels))

print("MNIST is ready. Classes:", labels)
# Out:
# Dataset prepared at: /home/zboucek/mygit/cf/aideck-gap8-examples/examples/ai/classification/training_data
# Found 834 images belonging to 2 classes.
# Found 208 images belonging to 2 classes.
# Class Indices: {'auto': 0, 'pozadí': 1}

# %% [markdown]
# ## Model Building and Training
#
# In this section, we will define the architecture of the neural network using MobileNetV3Small as the base model. The model will then be trained using the prepared dataset. The training will be conducted in two stages: initial training with frozen weights of the base model, and fine-tuning with unfrozen weights.

# %%
# Define the model architecture
base_model = MobileNetV3Small(
    input_shape=(244, 244, 3),
    include_top=False,
    weights="imagenet"
)
base_model.trainable = False  # Freeze the base model for initial training

if args.image_channels == 1:
    print("Detected grayscale images, adding conversion layer.")
    input_layer = tf.keras.Sequential([
        tf.keras.Input(shape=(args.image_width, args.image_height, 1)),
        tf.keras.layers.Conv2D(filters=3, kernel_size=(1, 1), activation=None),
        tf.keras.layers.Resizing(244, 244, interpolation="bilinear")
    ])
else:
    print("Detected RGB images, resizing only.")
    input_layer = tf.keras.Sequential([
        tf.keras.Input(shape=(args.image_width, args.image_height, 3)),
        tf.keras.layers.Resizing(244, 244, interpolation="bilinear")
    ])

# Add custom layers on top of the base model
model = Sequential([
    input_layer,
    base_model,
    GlobalAveragePooling2D(),
    Dropout(0.3),
    Dense(units=len(train_generator.class_indices), activation="softmax")
])

# Compile the model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.build(input_shape=(None, args.image_width, args.image_height, args.image_channels))
model.summary(expand_nested=True)
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Detected RGB images, resizing only.
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_6 (Sequential)   (None, 244, 244, 3)       0
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | resizing_3 (Resizing)      (None, 244, 244, 3)       0        |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  MobilenetV3small (Function  (None, 8, 8, 576)         939120
#  al)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_7 (InputLayer)       [(None, 244, 244, 3)]     0        |
# |                                                               |
# | rescaling_3 (Rescaling)    (None, 244, 244, 3)       0        |
# |                                                               |
# | Conv (Conv2D)              (None, 122, 122, 16)      432      |
# |                                                               |
# | Conv/BatchNorm (BatchNorm  (None, 122, 122, 16)      64       |
# | alization)                                                    |
# |                                                               |
# | tf.math.add_81 (TFOpLambd  (None, 122, 122, 16)      0        |
# | a)                                                            |
# |                                                               |
# | re_lu_96 (ReLU)            (None, 122, 122, 16)      0        |
# |                                                               |
# | tf.math.multiply_81 (TFOp  (None, 122, 122, 16)      0        |
# | Lambda)                                                       |
# |                                                               |
# | multiply_54 (Multiply)     (None, 122, 122, 16)      0        |
# |                                                               |
# | expanded_conv/depthwise/p  (None, 123, 123, 16)      0        |
# | ad (ZeroPadding2D)                                            |
# |                                                               |
# | expanded_conv/depthwise (  (None, 61, 61, 16)        144      |
# | DepthwiseConv2D)                                              |
# |                                                               |
# | expanded_conv/depthwise/B  (None, 61, 61, 16)        64       |
# | atchNorm (BatchNormalizat                                     |
# | ion)                                                          |
# |                                                               |
# | re_lu_97 (ReLU)            (None, 61, 61, 16)        0        |
# |                                                               |
# | expanded_conv/squeeze_exc  (None, 1, 1, 16)          0        |
# | ite/AvgPool (GlobalAverag                                     |
# | ePooling2D)                                                   |
# |                                                               |
# | expanded_conv/squeeze_exc  (None, 1, 1, 8)           136      |
# | ite/Conv (Conv2D)                                             |
# |                                                               |
# | expanded_conv/squeeze_exc  (None, 1, 1, 8)           0        |
# | ite/Relu (ReLU)                                               |
# |                                                               |
# | expanded_conv/squeeze_exc  (None, 1, 1, 16)          144      |
# | ite/Conv_1 (Conv2D)                                           |
# |                                                               |
# | tf.math.add_82 (TFOpLambd  (None, 1, 1, 16)          0        |
# | a)                                                            |
# |                                                               |
# | re_lu_98 (ReLU)            (None, 1, 1, 16)          0        |
# |                                                               |
# | tf.math.multiply_82 (TFOp  (None, 1, 1, 16)          0        |
# | Lambda)                                                       |
# |                                                               |
# | expanded_conv/squeeze_exc  (None, 61, 61, 16)        0        |
# | ite/Mul (Multiply)                                            |
# |                                                               |
# | expanded_conv/project (Co  (None, 61, 61, 16)        256      |
# | nv2D)                                                         |
# |                                                               |
# | expanded_conv/project/Bat  (None, 61, 61, 16)        64       |
# | chNorm (BatchNormalizatio                                     |
# | n)                                                            |
# |                                                               |
# | expanded_conv_1/expand (C  (None, 61, 61, 72)        1152     |
# | onv2D)                                                        |
# |                                                               |
# | expanded_conv_1/expand/Ba  (None, 61, 61, 72)        288      |
# | tchNorm (BatchNormalizati                                     |
# | on)                                                           |
# |                                                               |
# | re_lu_99 (ReLU)            (None, 61, 61, 72)        0        |
# |                                                               |
# | expanded_conv_1/depthwise  (None, 63, 63, 72)        0        |
# | /pad (ZeroPadding2D)                                          |
# |                                                               |
# | expanded_conv_1/depthwise  (None, 31, 31, 72)        648      |
# |  (DepthwiseConv2D)                                            |
# |                                                               |
# | expanded_conv_1/depthwise  (None, 31, 31, 72)        288      |
# | /BatchNorm (BatchNormaliz                                     |
# | ation)                                                        |
# |                                                               |
# | re_lu_100 (ReLU)           (None, 31, 31, 72)        0        |
# |                                                               |
# | expanded_conv_1/project (  (None, 31, 31, 24)        1728     |
# | Conv2D)                                                       |
# |                                                               |
# | expanded_conv_1/project/B  (None, 31, 31, 24)        96       |
# | atchNorm (BatchNormalizat                                     |
# | ion)                                                          |
# |                                                               |
# | expanded_conv_2/expand (C  (None, 31, 31, 88)        2112     |
# | onv2D)                                                        |
# |                                                               |
# | expanded_conv_2/expand/Ba  (None, 31, 31, 88)        352      |
# | tchNorm (BatchNormalizati                                     |
# | on)                                                           |
# |                                                               |
# | re_lu_101 (ReLU)           (None, 31, 31, 88)        0        |
# |                                                               |
# | expanded_conv_2/depthwise  (None, 31, 31, 88)        792      |
# |  (DepthwiseConv2D)                                            |
# |                                                               |
# | expanded_conv_2/depthwise  (None, 31, 31, 88)        352      |
# | /BatchNorm (BatchNormaliz                                     |
# | ation)                                                        |
# |                                                               |
# | re_lu_102 (ReLU)           (None, 31, 31, 88)        0        |
# |                                                               |
# | expanded_conv_2/project (  (None, 31, 31, 24)        2112     |
# | Conv2D)                                                       |
# |                                                               |
# | expanded_conv_2/project/B  (None, 31, 31, 24)        96       |
# | atchNorm (BatchNormalizat                                     |
# | ion)                                                          |
# |                                                               |
# | expanded_conv_2/Add (Add)  (None, 31, 31, 24)        0        |
# |                                                               |
# | expanded_conv_3/expand (C  (None, 31, 31, 96)        2304     |
# | onv2D)                                                        |
# |                                                               |
# | expanded_conv_3/expand/Ba  (None, 31, 31, 96)        384      |
# | tchNorm (BatchNormalizati                                     |
# | on)                                                           |
# |                                                               |
# | tf.math.add_83 (TFOpLambd  (None, 31, 31, 96)        0        |
# | a)                                                            |
# |                                                               |
# | re_lu_103 (ReLU)           (None, 31, 31, 96)        0        |
# |                                                               |
# | tf.math.multiply_83 (TFOp  (None, 31, 31, 96)        0        |
# | Lambda)                                                       |
# |                                                               |
# | multiply_55 (Multiply)     (None, 31, 31, 96)        0        |
# |                                                               |
# | expanded_conv_3/depthwise  (None, 35, 35, 96)        0        |
# | /pad (ZeroPadding2D)                                          |
# |                                                               |
# | expanded_conv_3/depthwise  (None, 16, 16, 96)        2400     |
# |  (DepthwiseConv2D)                                            |
# |                                                               |
# | expanded_conv_3/depthwise  (None, 16, 16, 96)        384      |
# | /BatchNorm (BatchNormaliz                                     |
# | ation)                                                        |
# |                                                               |
# | tf.math.add_84 (TFOpLambd  (None, 16, 16, 96)        0        |
# | a)                                                            |
# |                                                               |
# | re_lu_104 (ReLU)           (None, 16, 16, 96)        0        |
# |                                                               |
# | tf.math.multiply_84 (TFOp  (None, 16, 16, 96)        0        |
# | Lambda)                                                       |
# |                                                               |
# | multiply_56 (Multiply)     (None, 16, 16, 96)        0        |
# |                                                               |
# | expanded_conv_3/squeeze_e  (None, 1, 1, 96)          0        |
# | xcite/AvgPool (GlobalAver                                     |
# | agePooling2D)                                                 |
# |                                                               |
# | expanded_conv_3/squeeze_e  (None, 1, 1, 24)          2328     |
# | xcite/Conv (Conv2D)                                           |
# |                                                               |
# | expanded_conv_3/squeeze_e  (None, 1, 1, 24)          0        |
# | xcite/Relu (ReLU)                                             |
# |                                                               |
# | expanded_conv_3/squeeze_e  (None, 1, 1, 96)          2400     |
# | xcite/Conv_1 (Conv2D)                                         |
# |                                                               |
# | tf.math.add_85 (TFOpLambd  (None, 1, 1, 96)          0        |
# | a)                                                            |
# |                                                               |
# | re_lu_105 (ReLU)           (None, 1, 1, 96)          0        |
# |                                                               |
# | tf.math.multiply_85 (TFOp  (None, 1, 1, 96)          0        |
# | Lambda)                                                       |
# |                                                               |
# | expanded_conv_3/squeeze_e  (None, 16, 16, 96)        0        |
# | xcite/Mul (Multiply)                                          |
# |                                                               |
# | expanded_conv_3/project (  (None, 16, 16, 40)        3840     |
# | Conv2D)                                                       |
# |                                                               |
# | expanded_conv_3/project/B  (None, 16, 16, 40)        160      |
# | atchNorm (BatchNormalizat                                     |
# | ion)                                                          |
# |                                                               |
# | expanded_conv_4/expand (C  (None, 16, 16, 240)       9600     |
# | onv2D)                                                        |
# |                                                               |
# | expanded_conv_4/expand/Ba  (None, 16, 16, 240)       960      |
# | tchNorm (BatchNormalizati                                     |
# | on)                                                           |
# |                                                               |
# | tf.math.add_86 (TFOpLambd  (None, 16, 16, 240)       0        |
# | a)                                                            |
# |                                                               |
# | re_lu_106 (ReLU)           (None, 16, 16, 240)       0        |
# |                                                               |
# | tf.math.multiply_86 (TFOp  (None, 16, 16, 240)       0        |
# | Lambda)                                                       |
# |                                                               |
# | multiply_57 (Multiply)     (None, 16, 16, 240)       0        |
# |                                                               |
# | expanded_conv_4/depthwise  (None, 16, 16, 240)       6000     |
# |  (DepthwiseConv2D)                                            |
# |                                                               |
# | expanded_conv_4/depthwise  (None, 16, 16, 240)       960      |
# | /BatchNorm (BatchNormaliz                                     |
# | ation)                                                        |
# |                                                               |
# | tf.math.add_87 (TFOpLambd  (None, 16, 16, 240)       0        |
# | a)                                                            |
# |                                                               |
# | re_lu_107 (ReLU)           (None, 16, 16, 240)       0        |
# |                                                               |
# | tf.math.multiply_87 (TFOp  (None, 16, 16, 240)       0        |
# | Lambda)                                                       |
# |                                                               |
# | multiply_58 (Multiply)     (None, 16, 16, 240)       0        |
# |                                                               |
# | expanded_conv_4/squeeze_e  (None, 1, 1, 240)         0        |
# | xcite/AvgPool (GlobalAver                                     |
# | agePooling2D)                                                 |
# |                                                               |
# | expanded_conv_4/squeeze_e  (None, 1, 1, 64)          15424    |
# | xcite/Conv (Conv2D)                                           |
# |                                                               |
# | expanded_conv_4/squeeze_e  (None, 1, 1, 64)          0        |
# | xcite/Relu (ReLU)                                             |
# |                                                               |
# | expanded_conv_4/squeeze_e  (None, 1, 1, 240)         15600    |
# | xcite/Conv_1 (Conv2D)                                         |
# |                                                               |
# | tf.math.add_88 (TFOpLambd  (None, 1, 1, 240)         0        |
# | a)                                                            |
# |                                                               |
# | re_lu_108 (ReLU)           (None, 1, 1, 240)         0        |
# |                                                               |
# | tf.math.multiply_88 (TFOp  (None, 1, 1, 240)         0        |
# | Lambda)                                                       |
# |                                                               |
# | expanded_conv_4/squeeze_e  (None, 16, 16, 240)       0        |
# | xcite/Mul (Multiply)                                          |
# |                                                               |
# | expanded_conv_4/project (  (None, 16, 16, 40)        9600     |
# | Conv2D)                                                       |
# |                                                               |
# | expanded_conv_4/project/B  (None, 16, 16, 40)        160      |
# | atchNorm (BatchNormalizat                                     |
# | ion)                                                          |
# |                                                               |
# | expanded_conv_4/Add (Add)  (None, 16, 16, 40)        0        |
# |                                                               |
# | expanded_conv_5/expand (C  (None, 16, 16, 240)       9600     |
# | onv2D)                                                        |
# |                                                               |
# | expanded_conv_5/expand/Ba  (None, 16, 16, 240)       960      |
# | tchNorm (BatchNormalizati                                     |
# | on)                                                           |
# |                                                               |
# | tf.math.add_89 (TFOpLambd  (None, 16, 16, 240)       0        |
# | a)                                                            |
# |                                                               |
# | re_lu_109 (ReLU)           (None, 16, 16, 240)       0        |
# |                                                               |
# | tf.math.multiply_89 (TFOp  (None, 16, 16, 240)       0        |
# | Lambda)                                                       |
# |                                                               |
# | multiply_59 (Multiply)     (None, 16, 16, 240)       0        |
# |                                                               |
# | expanded_conv_5/depthwise  (None, 16, 16, 240)       6000     |
# |  (DepthwiseConv2D)                                            |
# |                                                               |
# | expanded_conv_5/depthwise  (None, 16, 16, 240)       960      |
# | /BatchNorm (BatchNormaliz                                     |
# | ation)                                                        |
# |                                                               |
# | tf.math.add_90 (TFOpLambd  (None, 16, 16, 240)       0        |
# | a)                                                            |
# |                                                               |
# | re_lu_110 (ReLU)           (None, 16, 16, 240)       0        |
# |                                                               |
# | tf.math.multiply_90 (TFOp  (None, 16, 16, 240)       0        |
# | Lambda)                                                       |
# |                                                               |
# | multiply_60 (Multiply)     (None, 16, 16, 240)       0        |
# |                                                               |
# | expanded_conv_5/squeeze_e  (None, 1, 1, 240)         0        |
# | xcite/AvgPool (GlobalAver                                     |
# | agePooling2D)                                                 |
# |                                                               |
# | expanded_conv_5/squeeze_e  (None, 1, 1, 64)          15424    |
# | xcite/Conv (Conv2D)                                           |
# |                                                               |
# | expanded_conv_5/squeeze_e  (None, 1, 1, 64)          0        |
# | xcite/Relu (ReLU)                                             |
# |                                                               |
# | expanded_conv_5/squeeze_e  (None, 1, 1, 240)         15600    |
# | xcite/Conv_1 (Conv2D)                                         |
# |                                                               |
# | tf.math.add_91 (TFOpLambd  (None, 1, 1, 240)         0        |
# | a)                                                            |
# |                                                               |
# | re_lu_111 (ReLU)           (None, 1, 1, 240)         0        |
# |                                                               |
# | tf.math.multiply_91 (TFOp  (None, 1, 1, 240)         0        |
# | Lambda)                                                       |
# |                                                               |
# | expanded_conv_5/squeeze_e  (None, 16, 16, 240)       0        |
# | xcite/Mul (Multiply)                                          |
# |                                                               |
# | expanded_conv_5/project (  (None, 16, 16, 40)        9600     |
# | Conv2D)                                                       |
# |                                                               |
# | expanded_conv_5/project/B  (None, 16, 16, 40)        160      |
# | atchNorm (BatchNormalizat                                     |
# | ion)                                                          |
# |                                                               |
# | expanded_conv_5/Add (Add)  (None, 16, 16, 40)        0        |
# |                                                               |
# | expanded_conv_6/expand (C  (None, 16, 16, 120)       4800     |
# | onv2D)                                                        |
# |                                                               |
# | expanded_conv_6/expand/Ba  (None, 16, 16, 120)       480      |
# | tchNorm (BatchNormalizati                                     |
# | on)                                                           |
# |                                                               |
# | tf.math.add_92 (TFOpLambd  (None, 16, 16, 120)       0        |
# | a)                                                            |
# |                                                               |
# | re_lu_112 (ReLU)           (None, 16, 16, 120)       0        |
# |                                                               |
# | tf.math.multiply_92 (TFOp  (None, 16, 16, 120)       0        |
# | Lambda)                                                       |
# |                                                               |
# | multiply_61 (Multiply)     (None, 16, 16, 120)       0        |
# |                                                               |
# | expanded_conv_6/depthwise  (None, 16, 16, 120)       3000     |
# |  (DepthwiseConv2D)                                            |
# |                                                               |
# | expanded_conv_6/depthwise  (None, 16, 16, 120)       480      |
# | /BatchNorm (BatchNormaliz                                     |
# | ation)                                                        |
# |                                                               |
# | tf.math.add_93 (TFOpLambd  (None, 16, 16, 120)       0        |
# | a)                                                            |
# |                                                               |
# | re_lu_113 (ReLU)           (None, 16, 16, 120)       0        |
# |                                                               |
# | tf.math.multiply_93 (TFOp  (None, 16, 16, 120)       0        |
# | Lambda)                                                       |
# |                                                               |
# | multiply_62 (Multiply)     (None, 16, 16, 120)       0        |
# |                                                               |
# | expanded_conv_6/squeeze_e  (None, 1, 1, 120)         0        |
# | xcite/AvgPool (GlobalAver                                     |
# | agePooling2D)                                                 |
# |                                                               |
# | expanded_conv_6/squeeze_e  (None, 1, 1, 32)          3872     |
# | xcite/Conv (Conv2D)                                           |
# |                                                               |
# | expanded_conv_6/squeeze_e  (None, 1, 1, 32)          0        |
# | xcite/Relu (ReLU)                                             |
# |                                                               |
# | expanded_conv_6/squeeze_e  (None, 1, 1, 120)         3960     |
# | xcite/Conv_1 (Conv2D)                                         |
# |                                                               |
# | tf.math.add_94 (TFOpLambd  (None, 1, 1, 120)         0        |
# | a)                                                            |
# |                                                               |
# | re_lu_114 (ReLU)           (None, 1, 1, 120)         0        |
# |                                                               |
# | tf.math.multiply_94 (TFOp  (None, 1, 1, 120)         0        |
# | Lambda)                                                       |
# |                                                               |
# | expanded_conv_6/squeeze_e  (None, 16, 16, 120)       0        |
# | xcite/Mul (Multiply)                                          |
# |                                                               |
# | expanded_conv_6/project (  (None, 16, 16, 48)        5760     |
# | Conv2D)                                                       |
# |                                                               |
# | expanded_conv_6/project/B  (None, 16, 16, 48)        192      |
# | atchNorm (BatchNormalizat                                     |
# | ion)                                                          |
# |                                                               |
# | expanded_conv_7/expand (C  (None, 16, 16, 144)       6912     |
# | onv2D)                                                        |
# |                                                               |
# | expanded_conv_7/expand/Ba  (None, 16, 16, 144)       576      |
# | tchNorm (BatchNormalizati                                     |
# | on)                                                           |
# |                                                               |
# | tf.math.add_95 (TFOpLambd  (None, 16, 16, 144)       0        |
# | a)                                                            |
# |                                                               |
# | re_lu_115 (ReLU)           (None, 16, 16, 144)       0        |
# |                                                               |
# | tf.math.multiply_95 (TFOp  (None, 16, 16, 144)       0        |
# | Lambda)                                                       |
# |                                                               |
# | multiply_63 (Multiply)     (None, 16, 16, 144)       0        |
# |                                                               |
# | expanded_conv_7/depthwise  (None, 16, 16, 144)       3600     |
# |  (DepthwiseConv2D)                                            |
# |                                                               |
# | expanded_conv_7/depthwise  (None, 16, 16, 144)       576      |
# | /BatchNorm (BatchNormaliz                                     |
# | ation)                                                        |
# |                                                               |
# | tf.math.add_96 (TFOpLambd  (None, 16, 16, 144)       0        |
# | a)                                                            |
# |                                                               |
# | re_lu_116 (ReLU)           (None, 16, 16, 144)       0        |
# |                                                               |
# | tf.math.multiply_96 (TFOp  (None, 16, 16, 144)       0        |
# | Lambda)                                                       |
# |                                                               |
# | multiply_64 (Multiply)     (None, 16, 16, 144)       0        |
# |                                                               |
# | expanded_conv_7/squeeze_e  (None, 1, 1, 144)         0        |
# | xcite/AvgPool (GlobalAver                                     |
# | agePooling2D)                                                 |
# |                                                               |
# | expanded_conv_7/squeeze_e  (None, 1, 1, 40)          5800     |
# | xcite/Conv (Conv2D)                                           |
# |                                                               |
# | expanded_conv_7/squeeze_e  (None, 1, 1, 40)          0        |
# | xcite/Relu (ReLU)                                             |
# |                                                               |
# | expanded_conv_7/squeeze_e  (None, 1, 1, 144)         5904     |
# | xcite/Conv_1 (Conv2D)                                         |
# |                                                               |
# | tf.math.add_97 (TFOpLambd  (None, 1, 1, 144)         0        |
# | a)                                                            |
# |                                                               |
# | re_lu_117 (ReLU)           (None, 1, 1, 144)         0        |
# |                                                               |
# | tf.math.multiply_97 (TFOp  (None, 1, 1, 144)         0        |
# | Lambda)                                                       |
# |                                                               |
# | expanded_conv_7/squeeze_e  (None, 16, 16, 144)       0        |
# | xcite/Mul (Multiply)                                          |
# |                                                               |
# | expanded_conv_7/project (  (None, 16, 16, 48)        6912     |
# | Conv2D)                                                       |
# |                                                               |
# | expanded_conv_7/project/B  (None, 16, 16, 48)        192      |
# | atchNorm (BatchNormalizat                                     |
# | ion)                                                          |
# |                                                               |
# | expanded_conv_7/Add (Add)  (None, 16, 16, 48)        0        |
# |                                                               |
# | expanded_conv_8/expand (C  (None, 16, 16, 288)       13824    |
# | onv2D)                                                        |
# |                                                               |
# | expanded_conv_8/expand/Ba  (None, 16, 16, 288)       1152     |
# | tchNorm (BatchNormalizati                                     |
# | on)                                                           |
# |                                                               |
# | tf.math.add_98 (TFOpLambd  (None, 16, 16, 288)       0        |
# | a)                                                            |
# |                                                               |
# | re_lu_118 (ReLU)           (None, 16, 16, 288)       0        |
# |                                                               |
# | tf.math.multiply_98 (TFOp  (None, 16, 16, 288)       0        |
# | Lambda)                                                       |
# |                                                               |
# | multiply_65 (Multiply)     (None, 16, 16, 288)       0        |
# |                                                               |
# | expanded_conv_8/depthwise  (None, 19, 19, 288)       0        |
# | /pad (ZeroPadding2D)                                          |
# |                                                               |
# | expanded_conv_8/depthwise  (None, 8, 8, 288)         7200     |
# |  (DepthwiseConv2D)                                            |
# |                                                               |
# | expanded_conv_8/depthwise  (None, 8, 8, 288)         1152     |
# | /BatchNorm (BatchNormaliz                                     |
# | ation)                                                        |
# |                                                               |
# | tf.math.add_99 (TFOpLambd  (None, 8, 8, 288)         0        |
# | a)                                                            |
# |                                                               |
# | re_lu_119 (ReLU)           (None, 8, 8, 288)         0        |
# |                                                               |
# | tf.math.multiply_99 (TFOp  (None, 8, 8, 288)         0        |
# | Lambda)                                                       |
# |                                                               |
# | multiply_66 (Multiply)     (None, 8, 8, 288)         0        |
# |                                                               |
# | expanded_conv_8/squeeze_e  (None, 1, 1, 288)         0        |
# | xcite/AvgPool (GlobalAver                                     |
# | agePooling2D)                                                 |
# |                                                               |
# | expanded_conv_8/squeeze_e  (None, 1, 1, 72)          20808    |
# | xcite/Conv (Conv2D)                                           |
# |                                                               |
# | expanded_conv_8/squeeze_e  (None, 1, 1, 72)          0        |
# | xcite/Relu (ReLU)                                             |
# |                                                               |
# | expanded_conv_8/squeeze_e  (None, 1, 1, 288)         21024    |
# | xcite/Conv_1 (Conv2D)                                         |
# |                                                               |
# | tf.math.add_100 (TFOpLamb  (None, 1, 1, 288)         0        |
# | da)                                                           |
# |                                                               |
# | re_lu_120 (ReLU)           (None, 1, 1, 288)         0        |
# |                                                               |
# | tf.math.multiply_100 (TFO  (None, 1, 1, 288)         0        |
# | pLambda)                                                      |
# |                                                               |
# | expanded_conv_8/squeeze_e  (None, 8, 8, 288)         0        |
# | xcite/Mul (Multiply)                                          |
# |                                                               |
# | expanded_conv_8/project (  (None, 8, 8, 96)          27648    |
# | Conv2D)                                                       |
# |                                                               |
# | expanded_conv_8/project/B  (None, 8, 8, 96)          384      |
# | atchNorm (BatchNormalizat                                     |
# | ion)                                                          |
# |                                                               |
# | expanded_conv_9/expand (C  (None, 8, 8, 576)         55296    |
# | onv2D)                                                        |
# |                                                               |
# | expanded_conv_9/expand/Ba  (None, 8, 8, 576)         2304     |
# | tchNorm (BatchNormalizati                                     |
# | on)                                                           |
# |                                                               |
# | tf.math.add_101 (TFOpLamb  (None, 8, 8, 576)         0        |
# | da)                                                           |
# |                                                               |
# | re_lu_121 (ReLU)           (None, 8, 8, 576)         0        |
# |                                                               |
# | tf.math.multiply_101 (TFO  (None, 8, 8, 576)         0        |
# | pLambda)                                                      |
# |                                                               |
# | multiply_67 (Multiply)     (None, 8, 8, 576)         0        |
# |                                                               |
# | expanded_conv_9/depthwise  (None, 8, 8, 576)         14400    |
# |  (DepthwiseConv2D)                                            |
# |                                                               |
# | expanded_conv_9/depthwise  (None, 8, 8, 576)         2304     |
# | /BatchNorm (BatchNormaliz                                     |
# | ation)                                                        |
# |                                                               |
# | tf.math.add_102 (TFOpLamb  (None, 8, 8, 576)         0        |
# | da)                                                           |
# |                                                               |
# | re_lu_122 (ReLU)           (None, 8, 8, 576)         0        |
# |                                                               |
# | tf.math.multiply_102 (TFO  (None, 8, 8, 576)         0        |
# | pLambda)                                                      |
# |                                                               |
# | multiply_68 (Multiply)     (None, 8, 8, 576)         0        |
# |                                                               |
# | expanded_conv_9/squeeze_e  (None, 1, 1, 576)         0        |
# | xcite/AvgPool (GlobalAver                                     |
# | agePooling2D)                                                 |
# |                                                               |
# | expanded_conv_9/squeeze_e  (None, 1, 1, 144)         83088    |
# | xcite/Conv (Conv2D)                                           |
# |                                                               |
# | expanded_conv_9/squeeze_e  (None, 1, 1, 144)         0        |
# | xcite/Relu (ReLU)                                             |
# |                                                               |
# | expanded_conv_9/squeeze_e  (None, 1, 1, 576)         83520    |
# | xcite/Conv_1 (Conv2D)                                         |
# |                                                               |
# | tf.math.add_103 (TFOpLamb  (None, 1, 1, 576)         0        |
# | da)                                                           |
# |                                                               |
# | re_lu_123 (ReLU)           (None, 1, 1, 576)         0        |
# |                                                               |
# | tf.math.multiply_103 (TFO  (None, 1, 1, 576)         0        |
# | pLambda)                                                      |
# |                                                               |
# | expanded_conv_9/squeeze_e  (None, 8, 8, 576)         0        |
# | xcite/Mul (Multiply)                                          |
# |                                                               |
# | expanded_conv_9/project (  (None, 8, 8, 96)          55296    |
# | Conv2D)                                                       |
# |                                                               |
# | expanded_conv_9/project/B  (None, 8, 8, 96)          384      |
# | atchNorm (BatchNormalizat                                     |
# | ion)                                                          |
# |                                                               |
# | expanded_conv_9/Add (Add)  (None, 8, 8, 96)          0        |
# |                                                               |
# | expanded_conv_10/expand (  (None, 8, 8, 576)         55296    |
# | Conv2D)                                                       |
# |                                                               |
# | expanded_conv_10/expand/B  (None, 8, 8, 576)         2304     |
# | atchNorm (BatchNormalizat                                     |
# | ion)                                                          |
# |                                                               |
# | tf.math.add_104 (TFOpLamb  (None, 8, 8, 576)         0        |
# | da)                                                           |
# |                                                               |
# | re_lu_124 (ReLU)           (None, 8, 8, 576)         0        |
# |                                                               |
# | tf.math.multiply_104 (TFO  (None, 8, 8, 576)         0        |
# | pLambda)                                                      |
# |                                                               |
# | multiply_69 (Multiply)     (None, 8, 8, 576)         0        |
# |                                                               |
# | expanded_conv_10/depthwis  (None, 8, 8, 576)         14400    |
# | e (DepthwiseConv2D)                                           |
# |                                                               |
# | expanded_conv_10/depthwis  (None, 8, 8, 576)         2304     |
# | e/BatchNorm (BatchNormali                                     |
# | zation)                                                       |
# |                                                               |
# | tf.math.add_105 (TFOpLamb  (None, 8, 8, 576)         0        |
# | da)                                                           |
# |                                                               |
# | re_lu_125 (ReLU)           (None, 8, 8, 576)         0        |
# |                                                               |
# | tf.math.multiply_105 (TFO  (None, 8, 8, 576)         0        |
# | pLambda)                                                      |
# |                                                               |
# | multiply_70 (Multiply)     (None, 8, 8, 576)         0        |
# |                                                               |
# | expanded_conv_10/squeeze_  (None, 1, 1, 576)         0        |
# | excite/AvgPool (GlobalAve                                     |
# | ragePooling2D)                                                |
# |                                                               |
# | expanded_conv_10/squeeze_  (None, 1, 1, 144)         83088    |
# | excite/Conv (Conv2D)                                          |
# |                                                               |
# | expanded_conv_10/squeeze_  (None, 1, 1, 144)         0        |
# | excite/Relu (ReLU)                                            |
# |                                                               |
# | expanded_conv_10/squeeze_  (None, 1, 1, 576)         83520    |
# | excite/Conv_1 (Conv2D)                                        |
# |                                                               |
# | tf.math.add_106 (TFOpLamb  (None, 1, 1, 576)         0        |
# | da)                                                           |
# |                                                               |
# | re_lu_126 (ReLU)           (None, 1, 1, 576)         0        |
# |                                                               |
# | tf.math.multiply_106 (TFO  (None, 1, 1, 576)         0        |
# | pLambda)                                                      |
# |                                                               |
# | expanded_conv_10/squeeze_  (None, 8, 8, 576)         0        |
# | excite/Mul (Multiply)                                         |
# |                                                               |
# | expanded_conv_10/project   (None, 8, 8, 96)          55296    |
# | (Conv2D)                                                      |
# |                                                               |
# | expanded_conv_10/project/  (None, 8, 8, 96)          384      |
# | BatchNorm (BatchNormaliza                                     |
# | tion)                                                         |
# |                                                               |
# | expanded_conv_10/Add (Add  (None, 8, 8, 96)          0        |
# | )                                                             |
# |                                                               |
# | Conv_1 (Conv2D)            (None, 8, 8, 576)         55296    |
# |                                                               |
# | Conv_1/BatchNorm (BatchNo  (None, 8, 8, 576)         2304     |
# | rmalization)                                                  |
# |                                                               |
# | tf.math.add_107 (TFOpLamb  (None, 8, 8, 576)         0        |
# | da)                                                           |
# |                                                               |
# | re_lu_127 (ReLU)           (None, 8, 8, 576)         0        |
# |                                                               |
# | tf.math.multiply_107 (TFO  (None, 8, 8, 576)         0        |
# | pLambda)                                                      |
# |                                                               |
# | multiply_71 (Multiply)     (None, 8, 8, 576)         0        |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  global_average_pooling2d_3  (None, 576)               0
#   (GlobalAveragePooling2D)
#
#  dropout_3 (Dropout)         (None, 576)               0
#
#  dense_3 (Dense)             (None, 2)                 1154
#
# =================================================================
# Total params: 940274 (3.59 MB)
# Trainable params: 1154 (4.51 KB)
# Non-trainable params: 939120 (3.58 MB)
# _________________________________________________________________

# %%
# Early stopping to terminate training when validation loss stops improving
early_stopping = EarlyStopping(
    monitor='val_loss',          # Monitors validation loss
    patience=5,                  # Number of epochs without improvement before stopping
    verbose=1,                   # Print messages when stopping
    restore_best_weights=True    # Reverts to the best weights after stopping
)

# Learning rate scheduler to reduce learning rate when validation loss plateaus
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',          # Monitors validation loss
    factor=0.5,                  # Reduces the learning rate by a factor (e.g., halves it)
    # cooldown=5,
    patience=3,                  # Number of epochs without improvement before reducing learning rate
    verbose=1,                   # Print messages when reducing learning rate
    min_lr=1e-6                  # Minimum allowed learning rate
)


# Train the model
max_epochs = args.epochs
history = model.fit(
    train_generator,                            # Training data generator
    validation_data=val_generator,              # Validation data generator
    epochs=max_epochs,                          # Maximum number of epochs
    callbacks=[early_stopping, lr_scheduler]    # List of callbacks
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 20
#       9 # Learning rate scheduler to reduce learning rate when validation loss plateaus
#      10 lr_scheduler = ReduceLROnPlateau(
#      11     monitor='val_loss',          # Monitors validation loss
#      12     factor=0.5,                  # Reduces the learning rate by a factor (e.g., halves it)
#    (...)
#      16     min_lr=1e-6                  # Minimum allowed learning rate
#      17 )
#      19 weights = compute_class_weight("balanced",
# ---> 20                                classes=np.arange(num_classes),
#      21                                y=labels)
#      22 class_weight = dict(enumerate(weights))
#      24 # Train the model
#
# NameError: name 'num_classes' is not defined

# %% [markdown]
# ## Saving the Trained Model without Fine-Tuning and Evaluating Its Performance
#
# Once the model has been trained, we save it for later use and evaluate its performance. The evaluation metrics include accuracy on both the training and validation datasets. This step ensures that the model is saved in a reusable format for conversion or deployment.

# %%
# Define paths to save the model
model_save_dir = os.path.join(os.getcwd(), "model")
os.makedirs(model_save_dir, exist_ok=True)
model_save_path = os.path.join(model_save_dir, "model_no_finetune.keras")

# Save the model in .keras format
model.save(model_save_path)
print(f"Model saved to: {model_save_path}")

# Evaluate the model on the validation dataset
val_loss, val_accuracy = model.evaluate(val_generator, verbose=1)
print(f"Validation Loss: {val_loss:.4f}")
print(f"Validation Accuracy: {val_accuracy:.4%}")
# Out:
# Model saved to: /home/zboucek/mygit/cf/aideck-gap8-examples/examples/ai/classification/model/model_no_finetune.keras
# 7/7 [==============================] - 2s 306ms/step - loss: 0.6921 - accuracy: 0.4904
# Validation Loss: 0.6921
# Validation Accuracy: 49.0385%

# %% [markdown]
# ## Training Progress without Fine-Tuning Visualization
#
# In this section, we visualize the training progress using loss and accuracy metrics for both training and validation data. These plots help us understand whether the model is improving over time and if there are signs of overfitting or underfitting.

# %%
import matplotlib.pyplot as plt

# Retrieve history data
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
epochs_range = range(len(train_loss))

# Plot Loss
plt.figure(figsize=(12, 6))
plt.plot(epochs_range, train_loss, label="Training Loss")
plt.plot(epochs_range, val_loss, label="Validation Loss")
plt.title("Training and Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc="upper right")
plt.grid(True)
plt.show()

# Plot Accuracy
plt.figure(figsize=(12, 6))
plt.plot(epochs_range, train_accuracy, label="Training Accuracy")
plt.plot(epochs_range, val_accuracy, label="Validation Accuracy")
plt.title("Training and Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# Predict on validation data
val_labels = val_generator.classes
val_predictions = model.predict(val_generator)
val_pred_classes = np.argmax(val_predictions, axis=1)

# Classification report
report = classification_report(val_labels, val_pred_classes, target_names=val_generator.class_indices.keys())
print("Classification Report:\n")
print(report)

# Confusion matrix
conf_matrix = confusion_matrix(val_labels, val_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=val_generator.class_indices.keys(), yticklabels=val_generator.class_indices.keys())
plt.title("Confusion Matrix")
plt.xlabel("Predicted Class")
plt.ylabel("True Class")
plt.show()
# Out:
# 7/7 [==============================] - 3s 296ms/step
# Classification Report:
#
#               precision    recall  f1-score   support
#
#         auto       0.50      1.00      0.67       104
#       pozadí       1.00      0.02      0.04       104
#
#     accuracy                           0.51       208
#    macro avg       0.75      0.51      0.35       208
# weighted avg       0.75      0.51      0.35       208

# %% [markdown]
# ## Saving the Trained Model and Evaluating Its Performance
#
# Once the model has been trained, we save it for later use and evaluate its performance. The evaluation metrics include accuracy on both the training and validation datasets. This step ensures that the model is saved in a reusable format for conversion or deployment.

# %%
# Define paths to save the model
model_save_dir = os.path.join(os.getcwd(), "model")
os.makedirs(model_save_dir, exist_ok=True)
model_save_path = os.path.join(model_save_dir, "model.keras")

# Save the model in .keras format
model.save(model_save_path)
print(f"Model saved to: {model_save_path}")

# Evaluate the model on the validation dataset
val_loss, val_accuracy = model.evaluate(val_generator, verbose=1)
print(f"Validation Loss: {val_loss:.4f}")
print(f"Validation Accuracy: {val_accuracy:.4%}")
# Out:
# Model saved to: /home/zboucek/mygit/cf/aideck-gap8-examples/examples/ai/classification/model/model.keras
# 7/7 [==============================] - 2s 267ms/step - loss: 0.6921 - accuracy: 0.4904
# Validation Loss: 0.6921
# Validation Accuracy: 49.0385%

# %% [markdown]
# # Fine-Tune MobileNetV3

# %%
# Unfreeze the base model for fine-tuning
base_model.trainable = True
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# Fine-tune the model
fine_tune_epochs = args.finetune_epochs
total_epochs = max_epochs + fine_tune_epochs
history_fine = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=total_epochs,
    initial_epoch=history.epoch[-1],
    callbacks=[early_stopping, lr_scheduler]  # Include callbacks
)
# Out:
# Epoch 80/120
# 27/27 [==============================] - 151s 5s/step - loss: 0.4273 - accuracy: 0.8369 - val_loss: 0.6969 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 81/120
# 27/27 [==============================] - 144s 5s/step - loss: 0.0618 - accuracy: 0.9880 - val_loss: 0.7474 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 82/120
# 27/27 [==============================] - 148s 5s/step - loss: 0.0400 - accuracy: 0.9928 - val_loss: 0.8422 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 83/120
# 27/27 [==============================] - ETA: 0s - loss: 0.0408 - accuracy: 0.9916
# Epoch 83: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 27/27 [==============================] - 173s 6s/step - loss: 0.0408 - accuracy: 0.9916 - val_loss: 0.9750 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 84/120
# 27/27 [==============================] - 189s 7s/step - loss: 0.0297 - accuracy: 0.9916 - val_loss: 1.1492 - val_accuracy: 0.5000 - lr: 5.0000e-05
# Epoch 85/120
# 27/27 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9952Restoring model weights from the end of the best epoch: 80.
# 27/27 [==============================] - 174s 6s/step - loss: 0.0213 - accuracy: 0.9952 - val_loss: 1.3135 - val_accuracy: 0.5000 - lr: 5.0000e-05
# Epoch 85: early stopping

# %% [markdown]
# ## Training Progress Visualization
#
# In this section, we visualize the training progress using loss and accuracy metrics for both training and validation data. These plots help us understand whether the model is improving over time and if there are signs of overfitting or underfitting.

# %%
import matplotlib.pyplot as plt

# Retrieve history data
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
epochs_range = range(len(train_loss))

# Plot Loss
plt.figure(figsize=(12, 6))
plt.plot(epochs_range, train_loss, label="Training Loss")
plt.plot(epochs_range, val_loss, label="Validation Loss")
plt.title("Training and Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc="upper right")
plt.grid(True)
plt.show()

# Plot Accuracy
plt.figure(figsize=(12, 6))
plt.plot(epochs_range, train_accuracy, label="Training Accuracy")
plt.plot(epochs_range, val_accuracy, label="Validation Accuracy")
plt.title("Training and Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# Predict on validation data
val_labels = val_generator.classes
val_predictions = model.predict(val_generator)
val_pred_classes = np.argmax(val_predictions, axis=1)

# Classification report
report = classification_report(val_labels, val_pred_classes, target_names=val_generator.class_indices.keys())
print("Classification Report:\n")
print(report)

# Confusion matrix
conf_matrix = confusion_matrix(val_labels, val_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=val_generator.class_indices.keys(), yticklabels=val_generator.class_indices.keys())
plt.title("Confusion Matrix")
plt.xlabel("Predicted Class")
plt.ylabel("True Class")
plt.show()
# Out:
# 7/7 [==============================] - 3s 304ms/step
# Classification Report:
#
#               precision    recall  f1-score   support
#
#         auto       0.00      0.00      0.00       104
#       pozadí       0.50      1.00      0.67       104
#
#     accuracy                           0.50       208
#    macro avg       0.25      0.50      0.33       208
# weighted avg       0.25      0.50      0.33       208
# /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## Display Predicted Class Probabilities
# In this section, we will display the predicted class probabilities for the validation dataset. This helps in understanding how confident the model is about its predictions for each sample.

# %%
# Display predicted class probabilities for validation data
val_labels = val_generator.classes
val_predictions = model.predict(val_generator)  # Probabilities for each class
val_pred_classes = np.argmax(val_predictions, axis=1)  # Predicted classes

# Display probabilities for the first 10 samples
for i in range(10):
    true_class = list(val_generator.class_indices.keys())[val_labels[i]]
    predicted_class = list(val_generator.class_indices.keys())[val_pred_classes[i]]
    confidence = val_predictions[i][val_pred_classes[i]] * 100  # Confidence of the predicted class
    print(f"Sample {i + 1}:")
    print(f"  True Class: {true_class}")
    print(f"  Predicted Class: {predicted_class}")
    print(f"  Confidence: {confidence:.2f}%")
    print()
# Out:
# 7/7 [==============================] - 2s 336ms/step
# Sample 1:
#   True Class: auto
#   Predicted Class: pozadí
#   Confidence: 54.37%
#
# Sample 2:
#   True Class: auto
#   Predicted Class: pozadí
#   Confidence: 54.40%
#
# Sample 3:
#   True Class: auto
#   Predicted Class: pozadí
#   Confidence: 54.39%
#
# Sample 4:
#   True Class: auto
#   Predicted Class: pozadí
#   Confidence: 54.38%
#
# Sample 5:
#   True Class: auto
#   Predicted Class: pozadí
#   Confidence: 54.45%
#
# Sample 6:
#   True Class: auto
#   Predicted Class: pozadí
#   Confidence: 54.42%
#
# Sample 7:
#   True Class: auto
#   Predicted Class: pozadí
#   Confidence: 54.39%
#
# Sample 8:
#   True Class: auto
#   Predicted Class: pozadí
#   Confidence: 54.42%
#
# Sample 9:
#   True Class: auto
#   Predicted Class: pozadí
#   Confidence: 54.42%
#
# Sample 10:
#   True Class: auto
#   Predicted Class: pozadí
#   Confidence: 54.44%

# %% [markdown]
# ## TensorFlow Lite Conversion and Quantization
#
# TensorFlow Lite (TFLite) is a lightweight version of TensorFlow that is designed for deploying machine learning models on mobile, edge, and IoT devices. In this section, we will:
#
# 1. Convert the trained Keras model to a TensorFlow Lite model.
# 2. Quantize the TensorFlow Lite model for reduced size and improved performance.

# %%
# Convert the trained Keras model to TensorFlow Lite format
tflite_converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = tflite_converter.convert()

# Save the TFLite model
tflite_model_path = "model/classification.tflite"
with open(tflite_model_path, "wb") as f:
    f.write(tflite_model)

print(f"TensorFlow Lite model saved at: {tflite_model_path}")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpxqfqicmw/assets
# INFO:tensorflow:Assets written to: /tmp/tmpxqfqicmw/assets
# TensorFlow Lite model saved at: model/classification.tflite
# 2025-05-26 09:41:34.945721: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2025-05-26 09:41:34.945746: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2025-05-26 09:41:34.945912: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpxqfqicmw
# 2025-05-26 09:41:34.965825: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2025-05-26 09:41:34.965855: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmpxqfqicmw
# 2025-05-26 09:41:35.037077: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2025-05-26 09:41:35.738815: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmpxqfqicmw
# 2025-05-26 09:41:35.960719: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 1014806 microseconds.

# %%
# Define a representative dataset generator for quantization
def representative_data_gen():
    # Iterace přes validační dataset nebo jiný vhodný dataset
    dataset_list = tf.data.Dataset.list_files(DATASET_PATH + "/*/*/*")
    for i, image_path in enumerate(dataset_list.take(100)):  # Limitujeme na 100 vzorků
        image = tf.io.read_file(image_path)
        image = tf.io.decode_png(image, channels=args.image_channels)  # Přizpůsobení počtu kanálů
        image = tf.image.resize(image, [args.image_width, args.image_height])
        image = tf.cast(image, tf.float32) / 255.0  # Normalizace
        image = tf.expand_dims(image, 0)  # Přidání dimenze pro batch
        yield [image]

# Configure the converter for quantization
tflite_converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_converter.representative_dataset = representative_data_gen
tflite_converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
tflite_converter.target_spec.supported_types = [tf.int8]
tflite_converter.inference_input_type = tf.uint8
tflite_converter.inference_output_type = tf.uint8

# Convert and save the quantized TFLite model
try:
    quantized_model = tflite_converter.convert()
    quantized_model_path = f"{ROOT_PATH}/model/classification_q.tflite"
    with open(quantized_model_path, "wb") as f:
        f.write(quantized_model)
    print(f"Quantized TFLite model saved at {quantized_model_path}")
except Exception as e:
    print(f"Error during quantization: {e}")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp0441_ixt/assets
# INFO:tensorflow:Assets written to: /tmp/tmp0441_ixt/assets
# /home/zboucek/anaconda3/envs/tf/lib/python3.11/site-packages/tensorflow/lite/python/convert.py:947: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# 2025-05-26 09:41:52.370536: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2025-05-26 09:41:52.370561: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2025-05-26 09:41:52.370724: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp0441_ixt
# 2025-05-26 09:41:52.403132: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2025-05-26 09:41:52.403163: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /tmp/tmp0441_ixt
# 2025-05-26 09:41:52.512110: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2025-05-26 09:41:53.437903: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /tmp/tmp0441_ixt
# 2025-05-26 09:41:53.725225: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 1354501 microseconds.
# Quantized TFLite model saved at /home/zboucek/mygit/cf/aideck-gap8-examples/examples/ai/classification/model/classification_q.tflite
# fully_quantize: 0, inference_type: 6, input_inference_type: UINT8, output_inference_type: UINT8

# %%
# Testing the model on validation data
batch_images, batch_labels = next(iter(val_generator))  # A single batch from the validation set
logits = model(batch_images)
prediction = np.argmax(logits, axis=1)
truth = np.argmax(batch_labels, axis=1)

keras_accuracy = tf.keras.metrics.Accuracy()
keras_accuracy.update_state(prediction, truth)
print(f"Raw Keras model accuracy: {keras_accuracy.result().numpy():.3%}")

# Helper function to set input tensor for the TFLite interpreter
def set_input_tensor(interpreter, input_image):
    input_details = interpreter.get_input_details()[0]
    tensor_index = input_details["index"]
    input_tensor = interpreter.tensor(tensor_index)()[0]
    input_tensor[:, :] = input_image

# Helper function to classify an image using the TFLite interpreter
def classify_image(interpreter, input_image):
    set_input_tensor(interpreter, input_image)
    interpreter.invoke()
    output_details = interpreter.get_output_details()[0]
    output = interpreter.get_tensor(output_details["index"])
    # Dequantize results
    scale, zero_point = output_details["quantization"]
    output = scale * (output - zero_point)
    return np.argmax(output)

# Perform inference using the quantized TFLite model
try:
    interpreter = tf.lite.Interpreter(model_path=quantized_model_path)
    interpreter.allocate_tensors()

    # Compare all predictions with ground truth
    tflite_accuracy = tf.keras.metrics.Accuracy()
    batch_prediction = []
    batch_truth = np.argmax(batch_labels, axis=1)

    for i in range(len(batch_images)):
        prediction = classify_image(interpreter, batch_images[i])
        batch_prediction.append(prediction)

    tflite_accuracy.update_state(batch_prediction, batch_truth)
    print(f"Quantized TFLite model accuracy: {tflite_accuracy.result().numpy():.3%}")
except Exception as e:
    print(f"Error testing quantized model: {e}")
# Out:
# Raw Keras model accuracy: 50.000%
# Quantized TFLite model accuracy: 50.000%
